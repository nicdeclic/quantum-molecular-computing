# %% [markdown]
# # Open Research Notes & Dynamic Notebooks
#
# 👉 **New to this site? Start reading here:**
# **[“Welcome To A New Branch Of Quantum
# Computing!”](posts/welcome/index.qmd)**
#
# ------------------------------------------------------------------------
